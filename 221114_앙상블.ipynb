# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#13.-앙상블과제" data-toc-modified-id="13.-앙상블과제-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>13. 앙상블과제</a></span><ul class="toc-item"><li><span><a href="#boston데이터를-가지고-집값을-예측하는-아래-3가지의-모델을-만들고-모델을-비교하고-최적-모델의-결과를-해석하세요" data-toc-modified-id="boston데이터를-가지고-집값을-예측하는-아래-3가지의-모델을-만들고-모델을-비교하고-최적-모델의-결과를-해석하세요-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>boston데이터를 가지고 집값을 예측하는 아래 3가지의 모델을 만들고 모델을 비교하고 최적 모델의 결과를 해석하세요</a></span><ul class="toc-item"><li><span><a href="#배깅" data-toc-modified-id="배깅-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>배깅</a></span></li><li><span><a href="#랜덤포래스트" data-toc-modified-id="랜덤포래스트-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>랜덤포래스트</a></span></li><li><span><a href="#부스팅" data-toc-modified-id="부스팅-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>부스팅</a></span></li></ul></li><li><span><a href="#titanic데이터를-가지고-생존율을-예측하는--아래-3가지의-모델을-만들고-모델을-비교하고-최적-모델의-결과를-해석하세요" data-toc-modified-id="titanic데이터를-가지고-생존율을-예측하는--아래-3가지의-모델을-만들고-모델을-비교하고-최적-모델의-결과를-해석하세요-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>titanic데이터를 가지고 생존율을 예측하는  아래 3가지의 모델을 만들고 모델을 비교하고 최적 모델의 결과를 해석하세요</a></span><ul class="toc-item"><li><span><a href="#배깅" data-toc-modified-id="배깅-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>배깅</a></span></li><li><span><a href="#랜덤포래스트" data-toc-modified-id="랜덤포래스트-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>랜덤포래스트</a></span></li><li><span><a href="#부스팅" data-toc-modified-id="부스팅-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>부스팅</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 13. 앙상블과제

# %% [markdown]
# ## boston데이터를 가지고 집값을 예측하는 아래 3가지의 모델을 만들고 모델을 비교하고 최적 모델의 결과를 해석하세요
#
# ### 배깅
# ### 랜덤포래스트
# ### 부스팅

# %%
import pandas as pd 
from sklearn.datasets import load_boston
boston= load_boston()
X = pd.DataFrame(boston.data,columns=boston.feature_names)
y = boston.target
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
#0. 전처리
from sklearn.model_selection import train_test_split
X.info() # 결측치 X
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 2022)

# 1. 의사결정나무
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import numpy as np


decisionTreeRegression = DecisionTreeRegressor()
param_grid = {'max_depth' : range(1,40,1), 'min_samples_split' : range(2,40,1)}
model = GridSearchCV(decisionTreeRegression, param_grid)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('OneDecisionTree_best_estimator : ', model.best_estimator_)
print('OneDecisionTree_train_score : ', model.score(X_train, y_train))
print('OneDecisionTree_test_score : ', model.score(X_test, y_test))
print('OneDecisionTree_RMSE : ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB
# OneDecisionTree_best_estimator :  DecisionTreeRegressor(max_depth=8, min_samples_split=19)
# OneDecisionTree_model_train_score :  0.9431380868890157
# OneDecisionTree_test_score :  0.7556882658455569
# OneDecisionTree_RMSE :  4.574761392745581

# %%
# 2. Bagging
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import GridSearchCV

baggingRegressor = BaggingRegressor(oob_score = True)
param_grid = {'n_estimators' : range(10,100,10)}
baggingRegressor = GridSearchCV(baggingRegressor, param_grid)
baggingRegressor.fit(X_train, y_train)

print('Bagging_get_params : ' , baggingRegressor.get_params)
print('Bagging_best_estimator : ', baggingRegressor.best_estimator_)
print('Bagging_best_estimator_.n_estimators : ', baggingRegressor.best_estimator_.n_estimators)

# oob_score 호출을 위해 Bagging 객체 재생성
model = BaggingRegressor(oob_score = True, n_estimators = baggingRegressor.best_estimator_.n_estimators )
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Bagging_train_score : ', model.score(X_train, y_train))
print('Bagging_test_score : ', model.score(X_test, y_test))
print(f"Bagging_oob_score : , {model.oob_score_}")
print('Bagging_RMSE : ', np.sqrt(mean_squared_error(y_test, y_pred)))

print('Bagging_feature_importance')
feature_importances = pd.DataFrame(np.mean([ tree.feature_importances_ for tree in model.estimators_], axis = 0))
feature_importances = pd.concat([pd.DataFrame(X.columns),feature_importances], axis = 1)
feature_importances.columns = ['var_name', 'var_value']
feature_importances = feature_importances.sort_values(['var_value'], ascending = False).reset_index(drop=True)
print(feature_importances)

import matplotlib.pyplot as plt
plt.barh(feature_importances['var_name'], feature_importances['var_value'], align = 'center')
plt.xlabel('feature_importance', size = 15)
plt.ylabel('feature', size = 15)
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:1204: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:1204: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:1204: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:1204: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# ...

# %%
# 3. 랜덤포레스트
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

randomForestRegressor = RandomForestRegressor(oob_score = True)
param_grid = {'n_estimators' : range(10,100,10)}
randomForestRegressor = GridSearchCV(randomForestRegressor, param_grid)
randomForestRegressor = randomForestRegressor.fit(X_train, y_train)

print('RandomForest_get_params : ', randomForestRegressor.get_params())
print('RandomForest_best_estimator : ', randomForestRegressor.best_estimator_)
print('RandomForest_best_estimator_.n_estimators : ', randomForestRegressor.best_estimator_.n_estimators)

# oob_score 호출을 위해 Bagging 객체 재생성
model = RandomForestRegressor(oob_score = True, n_estimators = randomForestRegressor.best_estimator_.n_estimators)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

print('RandomForest_train_score : ', model.score(X_train, y_train))
print('RandomForest_test_score : ', model.score(X_test, y_test))
print(f'RandomForest_oob_score : {model.oob_score_}')
print('RandomForest_RMSE : ', np.sqrt(mean_squared_error(y_test, y_pred)))

print('RandomForest_feature_importance')
feature_importances = pd.DataFrame(np.mean([tree.feature_importances_ for tree in model.estimators_], axis = 0))
feature_importances = pd.concat([pd.DataFrame(X.columns), feature_importances], axis = 1)
feature_importances.columns = ['var_name', 'var_value']
feature_importances = feature_importances.sort_values(['var_value'], ascending = False).reset_index(drop = True)

import matplotlib.pyplot as plt
plt.barh(feature_importances['var_name'], feature_importances['var_value'], align = 'center')
plt.xlabel('feature_importances', size = 15)
plt.ylabel('feature', size = 15)
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# ...

# %%
# 4. 부스팅
# 회귀계수에 영향을 많이 주는 변수만 추출, 발전 > 영향을 미치는 변수와 아닌 변수간 (성능) 차이 존재 > 마지막 성능을 높이고자 사용
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
import numpy as np
adaBoostRegressor = AdaBoostRegressor()
# learning_rate : 클수록 과소적합, 작을수록 과대적합
param_grid = {'learning_rate' : np.arange(0.01, 0.1, 0.02)} # 0.01 ~ 0.1 이전까지 0.02 씩 증가
model = GridSearchCV(adaBoostRegressor, param_grid)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('AdaBoost_best_estimator : ', model.best_estimator_)
print('AdaBoost_train_score : ', model.score(X_train, y_train))
print('AdaBoost_test_score : ', model.score(X_test, y_test))
print('AdaBoost_RMSE : ', np.sqrt(mean_squared_error(y_test, y_pred)))
print('AdaBoost_feature_importance')
feature_importances = pd.DataFrame(np.mean([tree.feature_importances_ for tree in model.best_estimator_.estimators_], axis = 0))
feature_importances = pd.concat([pd.DataFrame(X.columns), feature_importances], axis = 1)
feature_importances.columns = ['var_name', 'var_value']
feature_importances = feature_importances.sort_values(['var_value'], ascending = False).reset_index(drop = True)

import matplotlib.pyplot as plt
plt.barh(feature_importances['var_name'], feature_importances['var_value'], align = 'center')
plt.xlabel('feature_importances', size = 15)
plt.ylabel('feature', size = 15)
plt.show()
# Out:
# AdaBoost_best_estimator :  AdaBoostRegressor(learning_rate=0.01)
# AdaBoost_train_score :  0.5149731804264501
# AdaBoost_test_score :  0.44794603246615594
# AdaBoost_RMSE :  0.35934417934839863
# AdaBoost_feature_importance

# %%
# 참고 : 열별로 평균
list = [[1,3,2], [9,10,23], [45,12,34]]
list

temp = pd.DataFrame(np.mean([i for i in list],axis = 0))
print(temp)  
print((1+9+45) / 3)
print((3+10+12) / 3)
print((2+23+34) / 3)
# Out:
#            0
# 0  18.333333
# 1   8.333333
# 2  19.666667
# 18.333333333333332
# 8.333333333333334
# 19.666666666666668

# %% [markdown]
# ## titanic데이터를 가지고 생존율을 예측하는  아래 3가지의 모델을 만들고 모델을 비교하고 최적 모델의 결과를 해석하세요
#
# ### 배깅
# ### 랜덤포래스트
# ### 부스팅

# %%
import pandas as pd
df = pd.read_csv("data/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town
# ...

# %%
# 0. 전처리
import pandas as pd
from sklearn.model_selection import train_test_split

# 결측치 대치 필요: age, embarked(embark_town)
df.info() 
df['age'].fillna(df['age'].mean(), inplace = True)
df['embarked'].fillna(df['embarked'].value_counts().index[0], inplace = True)

# 중복컬럼삭제 필요
df.drop(['sex','class','embark_town'], axis = 1, inplace = True)

# 더미변수화 필요
df = pd.get_dummies(df,columns = ['embarked']) 

# 데이터 셋 분할
X = df.drop(columns = ['survived'])
y = df['survived']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 2022)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   adult_male   891 non-null    bool
#  10  embark_town  889 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 70.6+ KB
# (623, 9)
# (623,)
# (268, 9)
# (268,)

# %%
# 1. 의사결정나무
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.metrics import plot_roc_curve, roc_auc_score

decisionTreeClassifier = DecisionTreeClassifier()
param_grid = {'max_depth' : range(1,40,2), 'min_samples_leaf' : range(2,40,2)}
model = GridSearchCV(decisionTreeClassifier, param_grid)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('DecisionTreeClassifier_best_estimator : ', model.best_estimator_)
print('DecisionTreeClassifier_train_score : ', model.score(X_train,y_train))
print('DecisionTreeClassifier_test_score : ', model.score(X_test,y_test))

print('DecisionTreeClassifier_confusion_matrix')
print( pd.DataFrame(confusion_matrix(y_test, y_pred), index = ['True[0]', 'True[1]'], columns = ['Pred[0]', 'Pred[1]']))
print('DecisionTreeClassifier_accuracy_score : ', accuracy_score(y_test, y_pred))
print('DecisionTreeClassifier_recall_score : ', recall_score(y_test, y_pred))
print('DecisionTreeClassifier_precision_score : ', precision_score(y_test, y_pred))
print('DecisionTreeClassifier_classification_report')
print(classification_report(y_test, y_pred))

# ROC_SCORE
# bineary 분류일 때 : roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
# 다중 클래스 분류일 때 : roc_auc_score(y_test, clf.predict_proba(X_test), multi_class='ovr')
# 여러 개의 라벨을 분류할 때 : roc_auc_score(y, y_pred, average=None)
print('DecisionTreeClassifier_ROC_AUC_SCORE : ', roc_auc_score(y_test, model.predict_proba(X_test)[:,-1]))
# ROC 곡선 (X축 : 민감도, Y축 : 1-특이도(실제 False를 False라고 예측하는 비율))
print('DecisionTreeClassifier_ROC_CURVE') 
print(plot_roc_curve(model, X_test, y_test))
# Out:
# DecisionTreeClassifier_best_estimator :  DecisionTreeClassifier(max_depth=7, min_samples_leaf=10)
# DecisionTreeClassifier_train_score :  0.8667736757624398
# DecisionTreeClassifier_test_score :  0.8097014925373134
# DecisionTreeClassifier_confusion_matrix
#          Pred[0]  Pred[1]
# True[0]      152       16
# True[1]       35       65
# DecisionTreeClassifier_accuracy_score :  0.8097014925373134
# DecisionTreeClassifier_recall_score :  0.65
# DecisionTreeClassifier_precision_score :  0.8024691358024691
# DecisionTreeClassifier_classification_report
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.86       168
#            1       0.80      0.65      0.72       100
#
#     accuracy                           0.81       268
#    macro avg       0.81      0.78      0.79       268
# weighted avg       0.81      0.81      0.80       268
#
# DecisionTreeClassifier_ROC_AUC_SCORE :  0.8491964285714285
# DecisionTreeClassifier_ROC_CURVE
# ...

# %%
# 2. Bagging
from sklearn.ensemble import BaggingClassifier # base_estimator default = DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.metrics import plot_roc_curve, roc_auc_score
import matplotlib.pyplot as plt

baggingClassifier = BaggingClassifier(oob_score = True)
param_grid = {'n_estimators' : range(10,100,10)}
baggingClassifier = GridSearchCV(baggingClassifier, param_grid)
baggingClassifier.fit(X_train, y_train)
print('Bagging_get_params : ', baggingClassifier.get_params)
print('Bagging_best_estimator_ : ', baggingClassifier.best_estimator_)
print('Bagging_best_estimator_.n_estimators : ', baggingClassifier.best_estimator_.n_estimators)

model = BaggingClassifier(oob_score = True, n_estimators = baggingClassifier.best_estimator_.n_estimators)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('Bagging_train_score : ', model.score(X_train,y_train))
print('Bagging_test_score : ', model.score(X_test, y_test))
print('Bagging_oob_score : ', model.oob_score_ )
print('Bagging_confusion_matrix')
print(pd.DataFrame(confusion_matrix(y_test, y_pred), index = ['True[0]', 'True[1]'], columns = ['Pred[0]', 'Pred[1]']))
print('Bagging_accuracy_score : ', accuracy_score(y_test, y_pred))
print('Bagging_recall_score : ', recall_score(y_test, y_pred))
print('Bagging_precision_score : ', precision_score(y_test, y_pred))
print('Bagging_classification_report')
print(classification_report(y_test, y_pred))
print('Bagging_ROC_AUC_SCORE : ', roc_auc_score(y_test, model.predict_proba(X_test)[:,-1]))
print('Bagging_ROC_CURVE')
plot_roc_curve(model, X_test, y_test) # 파라미터 주의
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:747: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:753: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:747: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_bagging.py:753: RuntimeWarning: invalid value encountered in divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# ...

# %%
# 변수 중요도
import numpy as np
feature_importance = pd.DataFrame(np.mean([tree.feature_importances_ for tree in model.estimators_], axis = 0))
feature_importance = pd.concat([pd.DataFrame(X.columns), feature_importance], axis = 1)
feature_importance.columns = ['var_name', 'var_value']
feature_importance = feature_importance.sort_values(['var_value'], ascending = False)
print(feature_importance)
import matplotlib.pyplot as plt
plt.barh(feature_importance['var_name'], feature_importance['var_value'], align = 'center')
plt.xlabel('feature importance', size = 15)
plt.ylabel('feature', size = 15)
# Out:
#      var_name  var_value
# 5  adult_male   0.319994
# 4        fare   0.257440
# 1         age   0.218579
# 0      pclass   0.121106
# 2       sibsp   0.027095
# 3       parch   0.025017
# 6  embarked_C   0.012578
# 8  embarked_S   0.011657
# 7  embarked_Q   0.006534
# Text(0, 0.5, 'feature')

# %%
# 3. 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.metrics import plot_roc_curve, roc_auc_score

randomForestClassifier = RandomForestClassifier(oob_score = True)
param_grid = {'n_estimators' : range(10,100,10)}
randomForestClassifier = GridSearchCV(randomForestClassifier, param_grid)
randomForestClassifier.fit(X_train, y_train)

print('RandomForest_get_params : ', randomForestClassifier.get_params)
print('RandomForest_best_estimator_ : ', randomForestClassifier.best_estimator_)
print('RandomForest_best_estimator_.n_estimators : ', randomForestClassifier.best_estimator_.n_estimators)

model = RandomForestClassifier(oob_score = True, n_estimators = randomForestClassifier.best_estimator_.n_estimators)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('RandomForest_train_score : ', model.score(X_train, y_train))
print('RandomForest_test_score : ', model.score(X_test, y_test))
print('RandomForest_oob_score : ', model.oob_score_)

print('RandomForest_confusion_matrix')
print(pd.DataFrame(confusion_matrix(y_test, y_pred), index = ['True[0]', 'True[1]'], columns = ['Pred[0]', 'Pred[1]']))
print('RandomForest_accurancy_score : ', accuracy_score(y_test, y_pred) )
print('RandomForest_recall_score : ', recall_score(y_test, y_pred))
print('RandomForest_precision_score : ', precision_score(y_test, y_pred))
print('RandomForest_classification_report')
print(classification_report(y_test, y_pred))

print('RandomForest_ROC_AUC_SCORE : ', roc_auc_score(y_test, model.predict_proba(X_test)[:,-1]))
print('RandomForest_ROC_CURVE')
print(plot_roc_curve(model, X_test, y_test))
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# ...

# %%
# 변수중요도
import numpy as np
feature_importance = pd.DataFrame(np.mean([tree.feature_importances_ for tree in model.estimators_], axis = 0 ))
feature_importance = pd.concat([pd.DataFrame(X.columns), feature_importance], axis = 1)
feature_importance.columns = ['var_name', 'var_value']
feature_importance = feature_importance.sort_values(['var_value'], ascending = False).reset_index(drop = True)
print(feature_importance)

import matplotlib.pyplot as plt
plt.barh(feature_importance['var_name'], feature_importance['var_value'], align = 'center')
plt.xlabel('feature importance', size = 15)
plt.ylabel('feature', size = 15)
plt.show()
# Out:
#      var_name  var_value
# 0  adult_male   0.272790
# 1        fare   0.267760
# 2         age   0.232946
# 3      pclass   0.101686
# 4       sibsp   0.054558
# 5       parch   0.037411
# 6  embarked_S   0.015710
# 7  embarked_C   0.010699
# 8  embarked_Q   0.006440

# %%
# 4. 부스팅
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.metrics import plot_roc_curve, roc_auc_score
import numpy as np

adaBoostClassifier = AdaBoostClassifier()
param_grid = {'learning_rate' : np.arange(0.01, 0.1, 0.02)} # 0.01 ~ 0.1 이전까지 0.02 씩 증가
model = GridSearchCV(adaBoostClassifier, param_grid)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('AdaBoost_best_estimator_ : ', model.best_estimator_)
print('AdaBoost_train_score : ', model.score(X_train, y_train))
print('AdaBoost_test_score : ', model.score(X_test, y_test))


print('AdaBoost_confusion_matrix')
print(pd.DataFrame(confusion_matrix(y_test, y_pred), index = ['True[0]', 'True[1]'], columns = ['Pred[0]', 'Pred[1]']))
print('AdaBoost_accurancy_score : ', accuracy_score(y_test, y_pred))
print('AdaBoost_recall_score : ', recall_score(y_test, y_pred))
print('AdaBoost_precision_score : ', precision_score(y_test, y_pred))
print('AdaBoost_classification_report')
print(classification_report(y_test, y_pred))


print('AdaBoost_ROC_AUC_SCORE : ', roc_auc_score(y_test, model.predict_proba(X_test)[:,-1]))
print('AdaBoost_ROC_CURVE')
print(plot_roc_curve(model, X_test, y_test))
# Out:
# AdaBoost_best_estimator_ :  AdaBoostClassifier(learning_rate=0.08999999999999998)
# AdaBoost_train_score :  0.8234349919743178
# AdaBoost_test_score :  0.8097014925373134
# AdaBoost_confusion_matrix
#          Pred[0]  Pred[1]
# True[0]      146       22
# True[1]       29       71
# AdaBoost_accurancy_score :  0.8097014925373134
# AdaBoost_recall_score :  0.71
# AdaBoost_precision_score :  0.7634408602150538
# AdaBoost_classification_report
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       168
#            1       0.76      0.71      0.74       100
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.79      0.79       268
# weighted avg       0.81      0.81      0.81       268
#
# AdaBoost_ROC_AUC_SCORE :  0.8508035714285714
# AdaBoost_ROC_CURVE
# ...

# %%
# 변수중요도
# GridSearchCV > best_estimator_ 추가 작성 필요.
import numpy as np
feature_importance = pd.DataFrame(np.mean([tree.feature_importances_  for tree in model.best_estimator_.estimators_], axis = 0))
feature_importance = pd.DataFrame(pd.concat([pd.DataFrame(X.columns), feature_importance], axis = 1))
feature_importance.columns = ['var_name', 'var_value']
feature_importance = feature_importance.sort_values(['var_value'], ascending = False).reset_index(drop = True)
print(feature_importance)

import matplotlib.pyplot as plt

plt.barh(feature_importance['var_name'], feature_importance['var_value'], align = 'center')
plt.xlabel('feature importance', size = 15)
plt.ylabel('feature', size = 15)
plt.show()
# Out:
#      var_name  var_value
# 0  adult_male       0.44
# 1      pclass       0.22
# 2       sibsp       0.18
# 3        fare       0.16
# 4         age       0.00
# 5       parch       0.00
# 6  embarked_C       0.00
# 7  embarked_Q       0.00
# 8  embarked_S       0.00
